# %% [markdown]
# td dependent
# ppg
# adp
# consistencia
# underrated o overrated comparando el adp con el ranking final
# hacer una columna de si jugaron o no y hacer el promedio de la liga cuando jugaron y cuando no jugaron
# group bys por posicion y pts
# del top 10 de que equipos son hay equipos que ni figuran en ninguna posicion que record tuvieron?

# %%
import pandas as pd
import glob
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %%
week1 = pd.read_csv("data/data-master/data-master/weekly/2021/week1.csv")
week1['week'] = np.where(week1['Player'] == 1, '1','1' )
week2 = pd.read_csv("data/data-master/data-master/weekly/2021/week2.csv")
week2['week'] = np.where(week1['Player'] == 2, '2','2' )
week3 = pd.read_csv("data/data-master/data-master/weekly/2021/week3.csv")
week3['week'] = np.where(week1['Player'] == 3, '3','3' )
week4 = pd.read_csv("data/data-master/data-master/weekly/2021/week4.csv")
week4['week'] = np.where(week1['Player'] == 4, '4','4' )
week5 = pd.read_csv("data/data-master/data-master/weekly/2021/week5.csv")
week5['week'] = np.where(week1['Player'] == 5, '5','5' )
week6 = pd.read_csv("data/data-master/data-master/weekly/2021/week6.csv")
week6['week'] = np.where(week1['Player'] == 6, '6','6' )
week7 = pd.read_csv("data/data-master/data-master/weekly/2021/week7.csv")
week7['week'] = np.where(week1['Player'] == 7, '7','7' )
week8 = pd.read_csv("data/data-master/data-master/weekly/2021/week8.csv")
week8['week'] = np.where(week1['Player'] == 8, '8','8' )
week9 = pd.read_csv("data/data-master/data-master/weekly/2021/week9.csv")
week9['week'] = np.where(week1['Player'] == 9, '9','9' )
week10 = pd.read_csv("data/data-master/data-master/weekly/2021/week10.csv")
week10['week'] = np.where(week1['Player'] == 10, '10','10' )
week11 = pd.read_csv("data/data-master/data-master/weekly/2021/week11.csv")
week11['week'] = np.where(week1['Player'] == 11, '11','11' )
week12 = pd.read_csv("data/data-master/data-master/weekly/2021/week12.csv")
week12['week'] = np.where(week1['Player'] == 12, '12','12' )
week13 = pd.read_csv("data/data-master/data-master/weekly/2021/week13.csv")
week13['week'] = np.where(week1['Player'] == 13, '13','13' )
week14 = pd.read_csv("data/data-master/data-master/weekly/2021/week14.csv")
week14['week'] = np.where(week1['Player'] == 14, '14','14' )
week15 = pd.read_csv("data/data-master/data-master/weekly/2021/week15.csv")
week15['week'] = np.where(week1['Player'] == 15, '15','15' )
week16 = pd.read_csv("data/data-master/data-master/weekly/2021/week16.csv")
week16['week'] = np.where(week1['Player'] == 16, '16','16' )
week17 = pd.read_csv("data/data-master/data-master/weekly/2021/week17.csv")
week17['week'] = np.where(week1['Player'] == 17, '17','17' )
week18 = pd.read_csv("data/data-master/data-master/weekly/2021/week18.csv")
week18['week'] = np.where(week1['Player'] == 18, '18','18' )

# %% [markdown]
# le agrego la columna week para saber en que week tuvieron esos puntos

# %%
weekly = pd.concat([week1, week2, week3, week4, week5, week6, week7, week8, week9, week10, week11, week12, week13, week14, week15, week16, week17, week18 ], axis=0, ).reset_index()
weekly
# Out:
#       index  Unnamed: 0           Player Pos   Tm  PassingYds  PassingTD  Int  \
# 0         0           0     Amari Cooper  WR  DAL           0          0    0
# 1         1           1      Tyreek Hill  WR  KAN           0          0    0
# 2         2           2  Patrick Mahomes  QB  KAN         337          3    0
# 3         3           3     Deebo Samuel  WR  SFO           0          0    0
# 4         4           4     Kyler Murray  QB  ARI         289          4    1
# ...     ...         ...              ...  ..  ...         ...        ...  ...
# 7195    395         395    Ross Cockrell  CB  TAM           0          0    0
# 7196    396         396      AJ Cole III   P  LVR           0          0    0
# 7197    397         397       Dylan Cole  LB  TEN           0          0    0
# 7198    398         398     L.J. Collier  DE  SEA           0          0    0
# 7199    399         399    Jamie Collins  LB  NWE           0          0    0
#
# ...

# %% [markdown]
# junto los resultados de cada fecha en un solo df
# #ignore.index = True para que no se resetee en index despues de cada semana

# %%
weekly.describe()
# Out:
#              index   Unnamed: 0   PassingYds    PassingTD          Int  \
# count  7200.000000  7200.000000  7200.000000  7200.000000  7200.000000
# mean    199.500000   199.500000    18.415278     0.116667     0.059306
# std     115.477713   115.477713    66.391179     0.511298     0.323132
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      99.750000    99.750000     0.000000     0.000000     0.000000
# 50%     199.500000   199.500000     0.000000     0.000000     0.000000
# 75%     299.250000   299.250000     0.000000     0.000000     0.000000
# max     399.000000   399.000000   525.000000     5.000000     4.000000
#
#         PassingAtt          Cmp   RushingAtt   RushingYds    RushingTD  \
# count  7200.000000  7200.000000  7200.000000  7200.000000  7200.000000
# mean      2.588194     1.679722     1.998889     8.720139     0.070139
# std       9.156918     6.014261     4.613375    22.010665     0.299924
# ...

# %%
weekly1= weekly.drop(columns={'Unnamed: 0'})
weekly1.columns
# Out:
# Index(['index', 'Player', 'Pos', 'Tm', 'PassingYds', 'PassingTD', 'Int',
#        'PassingAtt', 'Cmp', 'RushingAtt', 'RushingYds', 'RushingTD', 'Rec',
#        'Tgt', 'ReceivingYds', 'ReceivingTD', 'FL', 'StandardFantasyPoints',
#        'PPRFantasyPoints', 'HalfPPRFantasyPoints', 'week'],
#       dtype='object')

# %%
weekly1.columns = ["index","player", "pos", "team", "pass_yds", "pass_td", "ints", "pass_att", "completions", "rush_att", "rush_yds", "rush_tds","rec", "tgts", "rec_yds", "rec_tds", "fum_lost", "std_pts", "ppr_pts", "halfppr_pts", "week"]
weekly1
# Out:
#       index           player pos team  pass_yds  pass_td  ints  pass_att  \
# 0         0     Amari Cooper  WR  DAL         0        0     0         0
# 1         1      Tyreek Hill  WR  KAN         0        0     0         0
# 2         2  Patrick Mahomes  QB  KAN       337        3     0        36
# 3         3     Deebo Samuel  WR  SFO         0        0     0         0
# 4         4     Kyler Murray  QB  ARI       289        4     1        32
# ...     ...              ...  ..  ...       ...      ...   ...       ...
# 7195    395    Ross Cockrell  CB  TAM         0        0     0         0
# 7196    396      AJ Cole III   P  LVR         0        0     0         0
# 7197    397       Dylan Cole  LB  TEN         0        0     0         0
# 7198    398     L.J. Collier  DE  SEA         0        0     0         0
# 7199    399    Jamie Collins  LB  NWE         0        0     0         0
#
#       completions  rush_att  ...  rush_tds  rec  tgts  rec_yds  rec_tds  \
# ...

# %% [markdown]
# cambio los nombres de las columnas

# %%
weekly1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# no hay filas duplicadas

# %%
weekly1.isnull().sum()
# Out:
# index          0
# player         0
# pos            0
# team           0
# pass_yds       0
# pass_td        0
# ints           0
# pass_att       0
# completions    0
# rush_att       0
# rush_yds       0
# rush_tds       0
# rec            0
# tgts           0
# rec_yds        0
# rec_tds        0
# fum_lost       0
# std_pts        0
# ppr_pts        0
# halfppr_pts    0
# week           0
# dtype: int64

# %% [markdown]
# no hay datos faltantes

# %%
weekly1.halfppr_pts.value_counts().sort_values(ascending= False)
# Out:
# 0.00     2202
# 1.40       80
# 1.10       80
# 1.20       76
# 1.30       69
#          ...
# 10.32       1
# 30.20       1
# 35.90       1
# 1.18        1
# 0.30        1
# Name: halfppr_pts, Length: 864, dtype: int64

# %% [markdown]
# hay 2202 datos con 0 en puntos finales estos datos no me sirven

# %%
weekly_1 = weekly1.loc[weekly1["halfppr_pts"] > 0]
weekly_1
# Out:
#       index           player pos team  pass_yds  pass_td  ints  pass_att  \
# 0         0     Amari Cooper  WR  DAL         0        0     0         0
# 1         1      Tyreek Hill  WR  KAN         0        0     0         0
# 2         2  Patrick Mahomes  QB  KAN       337        3     0        36
# 3         3     Deebo Samuel  WR  SFO         0        0     0         0
# 4         4     Kyler Murray  QB  ARI       289        4     1        32
# ...     ...              ...  ..  ...       ...      ...   ...       ...
# 7082    282   Devin Duvernay  WR  BAL         0        0     0         0
# 7083    283   Craig Reynolds  RB  DET         0        0     0         0
# 7084    284    Mekhi Sargent  RB  JAX         0        0     0         0
# 7085    285    DeeJay Dallas  RB  SEA         0        0     0         0
# 7086    286  Michael Palardy   P  MIA         0        0     0         0
#
#       completions  rush_att  ...  rush_tds  rec  tgts  rec_yds  rec_tds  \
# ...

# %%
weekly_1.halfppr_pts.value_counts().sort_values(ascending= False)
# Out:
# 1.40     80
# 1.10     80
# 1.20     76
# 1.30     69
# 1.60     61
#          ..
# 10.92     1
# 35.90     1
# 10.32     1
# 5.20      1
# 0.30      1
# Name: halfppr_pts, Length: 852, dtype: int64

# %% [markdown]
# elimine todos los jugadores que tuvieron 0 puntos

# %%
weekly_rb = weekly_1.loc[weekly1["pos"]== "RB"]
weekly_rb
# Out:
#       index               player pos team  pass_yds  pass_td  ints  pass_att  \
# 15       15            Joe Mixon  RB  CIN         0        0     0         0
# 16       16  Christian McCaffrey  RB  CAR         0        0     0         0
# 30       30      Jamaal Williams  RB  DET         0        0     0         0
# 31       31        D'Andre Swift  RB  DET         0        0     0         0
# 34       34        Melvin Gordon  RB  DEN         0        0     0         0
# ...     ...                  ...  ..  ...       ...      ...   ...       ...
# 7079    279         Kene Nwangwu  RB  MIN         0        0     0         0
# 7080    280      Ty'Son Williams  RB  BAL         0        0     0         0
# 7083    283       Craig Reynolds  RB  DET         0        0     0         0
# 7084    284        Mekhi Sargent  RB  JAX         0        0     0         0
# 7085    285        DeeJay Dallas  RB  SEA         0        0     0         0
#
# ...

# %%
weekly_wr = weekly_1.loc[weekly1["pos"]== "WR"]
weekly_wr
# Out:
#       index          player pos team  pass_yds  pass_td  ints  pass_att  \
# 0         0    Amari Cooper  WR  DAL         0        0     0         0
# 1         1     Tyreek Hill  WR  KAN         0        0     0         0
# 3         3    Deebo Samuel  WR  SFO         0        0     0         0
# 8         8    Adam Thielen  WR  MIN         0        0     0         0
# 12       12   Tyler Lockett  WR  SEA         0        0     0         0
# ...     ...             ...  ..  ...       ...      ...   ...       ...
# 7069    269     Tyreek Hill  WR  KAN         0        0     0         0
# 7070    270      Jeff Smith  WR  NYJ         0        0     0         0
# 7073    273  DeAndre Carter  WR  WAS         0        0     0         0
# 7075    275   Ty Montgomery  WR  NOR         0        0     0         0
# 7082    282  Devin Duvernay  WR  BAL         0        0     0         0
#
#       completions  rush_att  ...  rush_tds  rec  tgts  rec_yds  rec_tds  \
# ...

# %%
weekly_te = weekly_1.loc[weekly1["pos"]== "TE"]
weekly_te
# Out:
#       index          player pos team  pass_yds  pass_td  ints  pass_att  \
# 10       10   Darren Waller  TE  LVR         0        0     0         0
# 11       11  Rob Gronkowski  TE  TAM         0        0     0         0
# 26       26  T.J. Hockenson  TE  DET         0        0     0         0
# 27       27    Travis Kelce  TE  KAN         0        0     0         0
# 67       67   Juwan Johnson  TE  NOR         0        0     0         0
# ...     ...             ...  ..  ...       ...      ...   ...       ...
# 7062    262     Tyler Kroft  TE  NYJ         0        0     0         0
# 7064    264     Evan Engram  TE  NYG         0        0     0         0
# 7071    271     Geoff Swaim  TE  TEN         0        0     0         0
# 7076    276     Josh Oliver  TE  BAL         0        0     0         0
# 7078    278     Jonnu Smith  TE  NWE         0        0     0         0
#
#       completions  rush_att  ...  rush_tds  rec  tgts  rec_yds  rec_tds  \
# ...

# %%
weekly_qb = weekly_1.loc[weekly1["pos"]== "QB"]
weekly_qb
# Out:
#       index             player pos team  pass_yds  pass_td  ints  pass_att  \
# 2         2    Patrick Mahomes  QB  KAN       337        3     0        36
# 4         4       Kyler Murray  QB  ARI       289        4     1        32
# 5         5         Jared Goff  QB  DET       338        3     1        57
# 6         6          Tom Brady  QB  TAM       379        4     2        50
# 7         7       Dak Prescott  QB  DAL       403        3     1        58
# ...     ...                ...  ..  ...       ...      ...   ...       ...
# 6921    121      Brandon Allen  QB  CIN       136        1     0        29
# 6930    130        Jordan Love  QB  GNB       134        1     2        17
# 6983    183    Taylor Heinicke  QB  WAS       120        0     0        18
# 7038    238     Marcus Mariota  QB  LVR         4        0     0         1
# 7081    281  Mitchell Trubisky  QB  BUF        15        0     0         1
#
# ...

# %% [markdown]
# creo un df semanal para cada posicion.

# %%
df_year = pd.read_csv('data/data-master/data-master/yearly/2021.csv')
yearly = df_year.drop(columns={'Unnamed: 0'})

# %%
yearly
# Out:
#                 Player   Tm  Pos  Age   G  GS    Tgt    Rec  PassingYds  \
# 0    Jonathan Taylor*+  IND   RB   22  17  17   51.0   40.0         0.0
# 1        Cooper Kupp*+  LAR   WR   28  17  17  191.0  145.0         0.0
# 2       Deebo Samuel*+  SFO   WR   25  16  15  121.0   77.0        24.0
# 3           Josh Allen  BUF   QB   25  17  17    0.0    0.0      4407.0
# 4        Austin Ekeler  LAC   RB   26  16  16   94.0   70.0         0.0
# ..                 ...  ...  ...  ...  ..  ..    ...    ...         ...
# 666    Travis Benjamin  SFO  NaN   32  10   0    5.0    0.0         0.0
# 667     Trenton Cannon  2TM   RB   27  12   0    0.0    0.0         0.0
# 668       John Wolford  LAR   QB   26   3   0    0.0    0.0         5.0
# 669         Josh Rosen  ATL   QB   24   4   0    0.0    0.0        19.0
# 670    Diontae Spencer  DEN   WR   29  15   0    4.0    1.0         0.0
#
#      PassingTD  PassingAtt  RushingYds  RushingTD  RushingAtt  ReceivingYds  \
# ...

# %% [markdown]
# creo el df de los resultados finales del año

# %%
yearly.columns
# Out:
# Index(['Player', 'Tm', 'Pos', 'Age', 'G', 'GS', 'Tgt', 'Rec', 'PassingYds',
#        'PassingTD', 'PassingAtt', 'RushingYds', 'RushingTD', 'RushingAtt',
#        'ReceivingYds', 'ReceivingTD', 'FantasyPoints', 'Int', 'Fumbles',
#        'FumblesLost'],
#       dtype='object')

# %%
yearly.columns = ["player", "team", "pos", "age", "games", "games_started", "targets", "rec", "pass_yds", "pass_tds", "pass_att","rushing_yds", "rushing_tds", "rushing_att", "rec_yds", "rec_tds", "pts", "ints", "fumbles", "fumbles_lost"]
yearly_1 = yearly.loc[yearly["pts"] >0 ]
yearly_1
# Out:
#                 player team pos  age  games  games_started  targets    rec  \
# 0    Jonathan Taylor*+  IND  RB   22     17             17     51.0   40.0
# 1        Cooper Kupp*+  LAR  WR   28     17             17    191.0  145.0
# 2       Deebo Samuel*+  SFO  WR   25     16             15    121.0   77.0
# 3           Josh Allen  BUF  QB   25     17             17      0.0    0.0
# 4        Austin Ekeler  LAC  RB   26     16             16     94.0   70.0
# ..                 ...  ...  ..  ...    ...            ...      ...    ...
# 567       Luke Stocker  MIN  TE   33     12              0      2.0    2.0
# 568     Eric Tomlinson  BAL  TE   29     17              7      1.0    1.0
# 569    Tyrell Williams  DET  WR   29      1              1      3.0    2.0
# 570      Easop Winston  NOR  WR   25      3              1      1.0    1.0
# 571         Ethan Wolf  NOR  TE   26      2              1      2.0    2.0
#
# ...

# %% [markdown]
# cambio los nombres de las columnas y saco los jugadores con 0 puntos

# %%
def record(x):
    if x == "IND":
        return "8-9"
    elif x == "LAR":
        return "12-5"
    elif x == "SFO":
        return "10-7"
    elif x == "BUF":
        return "11-6"
    elif x == "LAC":
        return "9-8"
    elif x == "TAM":
        return "13-4"
    elif x == "BAL":
        return "8-9"
    elif x == "CIN":
        return "10-7"
    elif x == "MIN":
        return "8-9"
    elif x == "GNB":
        return "13-4"
    elif x == "KAN":
        return "12-5"
    elif x == "PIT":
        return "9-7-1"
    elif x == "ARI":
        return "11-6"
    elif x == "SEA":
        return "7-10"
    elif x == "PHI":
        return "9-8"
    elif x == "NWE":
        return "10-7"
    elif x == "NOR":
        return "9-8"
    elif x == "WAS":
        return "7-10"
    elif x == "MIA":
        return "9-8"
    elif x == "CHI":
        return "6-11"
    elif x == "DET":
        return "3-13-1"
    elif x == "JAX":
        return "3-14"
    elif x == "NYJ":
        return "4-13"
    elif x == "NYG":
        return "4-13"
    elif x == "HOU":
        return "4-13"
    elif x == "ATL":
        return "7-10"
    elif x == "LVR":
        return "10-7"
    elif x == "TEN":
        return "12-5"
    elif x == "CAR":
        return "5-12"
    elif x == "DEN":
        return "7-10"
    elif x == "CLE":
        return "8-9"
    elif x == "LAR":
        return "12-5"
    elif x == "DAL":
        return "12-5"
    else:
        return 0
yearly_1["record"] = yearly_1["team"].apply(record)
yearly_1
# Out:
# <ipython-input-42-3ddd525bc68f>:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yearly_1["record"] = yearly_1["team"].apply(record)
#                 player team pos  age  games  games_started  targets    rec  \
# 0    Jonathan Taylor*+  IND  RB   22     17             17     51.0   40.0
# 1        Cooper Kupp*+  LAR  WR   28     17             17    191.0  145.0
# 2       Deebo Samuel*+  SFO  WR   25     16             15    121.0   77.0
# 3           Josh Allen  BUF  QB   25     17             17      0.0    0.0
# 4        Austin Ekeler  LAC  RB   26     16             16     94.0   70.0
# ..                 ...  ...  ..  ...    ...            ...      ...    ...
# ...

# %% [markdown]
# le agrego la columna con el record del equipo

# %%
def loses(x):
    if x == "IND":
        return 9
    elif x == "LAR":
        return 5
    elif x == "SFO":
        return 7
    elif x == "BUF":
        return 6
    elif x == "LAC":
        return 8
    elif x == "TAM":
        return 4
    elif x == "BAL":
        return 9
    elif x == "CIN":
        return 7
    elif x == "MIN":
        return 9
    elif x == "GNB":
        return 4
    elif x == "KAN":
        return 5
    elif x == "PIT":
        return 7
    elif x == "ARI":
        return 6
    elif x == "SEA":
        return 10
    elif x == "PHI":
        return 8
    elif x == "NWE":
        return 7
    elif x == "NOR":
        return 8
    elif x == "WAS":
        return 10
    elif x == "MIA":
        return 8
    elif x == "CHI":
        return 11
    elif x == "DET":
        return 13
    elif x == "JAX":
        return 14
    elif x == "NYJ":
        return 13
    elif x == "NYG":
        return 13
    elif x == "HOU":
        return 13
    elif x == "ATL":
        return 10
    elif x == "LVR":
        return 7
    elif x == "TEN":
        return 5
    elif x == "CAR":
        return 12
    elif x == "DEN":
        return 10
    elif x == "CLE":
        return 9
    elif x == "LAR":
        return 5
    elif x == "DAL":
        return 5
    else:
        return 0
yearly_1["loses"] = yearly_1["team"].apply(loses)
yearly_1
# Out:
# <ipython-input-43-fb56c3778a40>:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yearly_1["loses"] = yearly_1["team"].apply(loses)
#                 player team pos  age  games  games_started  targets    rec  \
# 0    Jonathan Taylor*+  IND  RB   22     17             17     51.0   40.0
# 1        Cooper Kupp*+  LAR  WR   28     17             17    191.0  145.0
# 2       Deebo Samuel*+  SFO  WR   25     16             15    121.0   77.0
# 3           Josh Allen  BUF  QB   25     17             17      0.0    0.0
# 4        Austin Ekeler  LAC  RB   26     16             16     94.0   70.0
# ..                 ...  ...  ..  ...    ...            ...      ...    ...
# ...

# %% [markdown]
# agrego la columna con cantidad de partidos perdidos a cada equipo

# %%
def wins(x):
    if x == "IND":
        return 8
    elif x == "LAR":
        return 12
    elif x == "SFO":
        return 10
    elif x == "BUF":
        return 11
    elif x == "LAC":
        return 9
    elif x == "TAM":
        return 13
    elif x == "BAL":
        return 8
    elif x == "CIN":
        return 10
    elif x == "MIN":
        return 8
    elif x == "GNB":
        return 13
    elif x == "KAN":
        return 12
    elif x == "PIT":
        return 9
    elif x == "ARI":
        return 11
    elif x == "SEA":
        return 7
    elif x == "PHI":
        return 9
    elif x == "NWE":
        return 10
    elif x == "NOR":
        return 9
    elif x == "WAS":
        return 7
    elif x == "MIA":
        return 9
    elif x == "CHI":
        return 6
    elif x == "DET":
        return 3
    elif x == "JAX":
        return 3
    elif x == "NYJ":
        return 4
    elif x == "NYG":
        return 4
    elif x == "HOU":
        return 4
    elif x == "ATL":
        return 7
    elif x == "LVR":
        return 10
    elif x == "TEN":
        return 12
    elif x == "CAR":
        return 5
    elif x == "DEN":
        return 7
    elif x == "CLE":
        return 8
    elif x == "LAR":
        return 12
    elif x == "DAL":
        return 12
    else:
        return 0
yearly_1["wins"] = yearly_1["team"].apply(wins)
yearly_1
# Out:
# <ipython-input-44-69f537bfe5ed>:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yearly_1["wins"] = yearly_1["team"].apply(wins)
#                 player team pos  age  games  games_started  targets    rec  \
# 0    Jonathan Taylor*+  IND  RB   22     17             17     51.0   40.0
# 1        Cooper Kupp*+  LAR  WR   28     17             17    191.0  145.0
# 2       Deebo Samuel*+  SFO  WR   25     16             15    121.0   77.0
# 3           Josh Allen  BUF  QB   25     17             17      0.0    0.0
# 4        Austin Ekeler  LAC  RB   26     16             16     94.0   70.0
# ..                 ...  ...  ..  ...    ...            ...      ...    ...
# ...

# %% [markdown]
# agrego la columna con cantidad de partidos ganados a cada equipo

# %%
yearly_1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# no hay duplicados

# %%
(yearly_1.isnull().sum().sort_values()/len(yearly_1))*100
# Out:
# player           0.000000
# record           0.000000
# fumbles_lost     0.000000
# fumbles          0.000000
# ints             0.000000
# pts              0.000000
# rec_tds          0.000000
# rec_yds          0.000000
# rushing_att      0.000000
# rushing_tds      0.000000
# loses            0.000000
# rushing_yds      0.000000
# pass_tds         0.000000
# pass_yds         0.000000
# rec              0.000000
# targets          0.000000
# games_started    0.000000
# games            0.000000
# age              0.000000
# team             0.000000
# pass_att         0.000000
# wins             0.000000
# pos              0.175439
# dtype: float64

# %% [markdown]
# solo un 1.7% del df esta incompleto en la posicion

# %%
yearly_1.dtypes
# Out:
# player            object
# team              object
# pos               object
# age                int64
# games              int64
# games_started      int64
# targets          float64
# rec              float64
# pass_yds         float64
# pass_tds         float64
# pass_att         float64
# rushing_yds      float64
# rushing_tds      float64
# rushing_att      float64
# rec_yds          float64
# rec_tds          float64
# pts              float64
# ints             float64
# fumbles          float64
# fumbles_lost     float64
# record            object
# loses              int64
# wins               int64
# dtype: object

# %%
yearly.pts = yearly.pts.fillna(0)
yearly.pts = yearly.pts.astype(int)
yearly_by = yearly_1.groupby("pos")
yearly_by_pos = yearly_by[["pos", "pts"]].sum()
yearly_by_pos
# Out:
#          pts
# pos
# QB    9213.0
# RB    9981.0
# TE    4023.0
# WR   12006.0

# %% [markdown]
# pts tot por posicion

# %%
plt.style.use('ggplot')
plt.title('Puntos por posicion')
plt.pie(x= yearly_by_pos["pts"], labels= ["QB", "RB","TE", "WR"] , autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22c6fb83190>,
# ...
#  [Text(0.7490577526368304, 0.8055510432087225, 'QB'),
#   Text(-0.9029157455728671, 0.6282858874720916, 'RB'),
#   Text(-0.8815764826003625, -0.6578927764658713, 'TE'),
#   Text(0.5273324622317752, -0.9653602821105566, 'WR')],
#  [Text(0.4085769559837256, 0.4393914781138486, '26.16%'),
#   Text(-0.4924994975852002, 0.34270139316659537, '28.34%'),
#   Text(-0.48085989960019765, -0.35885060534502067, '11.42%'),
#   Text(0.28763588849005917, -0.5265601538784853, '34.09%')])

# %% [markdown]
# cuantos pts hicieron porcentualmente por posicion, los wr's son los que mas pts hicieron seguidos por los rb, qb y por ultimo los TE

# %%
yearly_te = yearly_1.loc[yearly_1["pos"]== "TE"]
yearly_te_rel = yearly_te.head(10)
plt.style.use('ggplot')
plt.title('TEs mas relevantes')
plt.pie(x= yearly_te_rel["pts"], labels= yearly_te_rel["player"] , autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22c71c5b310>,
# ...
#  [Text(0.9800464938211696, 0.4995086285028844, 'Mark Andrews*+'),
#   Text(0.23210022637898167, 1.0752346185437045, 'Travis Kelce*'),
#   Text(-0.5476837859959474, 0.9539614617777521, 'Dalton Schultz'),
#   Text(-1.0031530970195437, 0.45131348743428684, 'George Kittle*'),
#   Text(-1.0845778111227549, -0.1835510055003081, 'Rob Gronkowski'),
#   Text(-0.8204925581546649, -0.732660877905197, 'Dawson Knox'),
#   Text(-0.3097892642168407, -1.055476485657539, 'Hunter Henry'),
#   Text(0.2788881361642043, -1.0640589304671317, 'Dallas Goedert'),
#   Text(0.7782897831020157, -0.7773448485189939, 'Kyle Pitts*'),
#   Text(1.0630354473938188, -0.2827642791871417, 'Zach Ertz')],
#  [Text(0.534570814811547, 0.27245925191066417, '15.00%'),
#   Text(0.12660012347944452, 0.5864916101147478, '13.23%'),
#   Text(-0.29873661054324396, 0.5203426155151374, '10.13%'),
#   Text(-0.5471744165561147, 0.24617099314597463, '9.82%'),
# ...

# %% [markdown]
# cuales fueron los 10 TE con mas pts

# %%
yearly_wr = yearly_1.loc[yearly_1["pos"]== "WR"]
yearly_wr_rel = yearly_wr.head(10)
plt.style.use('ggplot')
plt.title('WRs mas relevantes')
plt.pie(x= yearly_wr_rel["pts"], labels= yearly_wr_rel["player"] , autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22c71ce6220>,
# ...
#  [Text(0.9967473090328928, 0.46529001916620477, 'Cooper Kupp*+'),
#   Text(0.334958670344914, 1.047760797682738, 'Deebo Samuel*+'),
#   Text(-0.43856588883064407, 1.0087913367759398, "Ja'Marr Chase*"),
#   Text(-0.9651274217608075, 0.5277585241048567, 'Justin Jefferson*'),
#   Text(-1.086735971817372, -0.17030833085363833, 'Davante Adams*+'),
#   Text(-0.7954601243459309, -0.7597652206935747, 'Mike Evans*'),
#   Text(-0.27551438092056196, -1.0649374751157739, 'Tyreek Hill*'),
#   Text(0.3178518130985671, -1.053076552255321, 'Stefon Diggs*'),
#   Text(0.8021775600271813, -0.752669357811807, 'Mike Williams'),
#   Text(1.0657486016732294, -0.2723599053303483, 'D.K. Metcalf')],
#  [Text(0.5436803503815778, 0.2537945559088389, '13.90%'),
#   Text(0.18270472927904396, 0.5715058896451298, '12.35%'),
#   Text(-0.23921775754398764, 0.5502498200596034, '10.56%'),
#   Text(-0.5264331391422585, 0.28786828587537633, '10.46%'),
# ...

# %% [markdown]
# cuales fueron los 10 WR con mas pts

# %%
yearly_rb = yearly_1.loc[yearly_1["pos"]== "RB"]
yearly_rb_rel = yearly_rb.head(10)
plt.style.use('ggplot')
plt.title('WRs mas relevantes')
plt.pie(x= yearly_rb_rel["pts"], labels= yearly_rb_rel["player"] , autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22c71d68250>,
# ...
#  [Text(0.9850389076642474, 0.4895899819110134, 'Jonathan Taylor*+'),
#   Text(0.2920529162524916, 1.0605211426975019, 'Austin Ekeler'),
#   Text(-0.4800159619629416, 0.9897397012653337, 'Joe Mixon*'),
#   Text(-0.9836788420864178, 0.49231690569340064, 'Najee Harris*'),
#   Text(-1.0865523348822248, -0.1714760145384363, 'James Conner*'),
#   Text(-0.8073925946572774, -0.7470724182384125, 'Ezekiel Elliott'),
#   Text(-0.2935216033797738, -1.0601155919754066, 'Nick Chubb*'),
#   Text(0.28911391349765897, -1.0613261256664082, 'Damien Harris'),
#   Text(0.7831859185238137, -0.7724116888201592, 'Alvin Kamara*'),
#   Text(1.0633030813733282, -0.281756201603417, 'Antonio Gibson')],
#  [Text(0.537293949635044, 0.2670490810423709, '14.68%'),
#   Text(0.1593015906831772, 0.5784660778350009, '12.08%'),
#   Text(-0.26182688834342266, 0.5398580188720001, '10.85%'),
#   Text(-0.5365520956835005, 0.2685364940145821, '10.01%'),
# ...

# %% [markdown]
# cuales fueron los 10 RB con mas pts

# %%
yearly_qb = yearly_1.loc[yearly_1["pos"]== "QB"]
yearly_qb_rel = yearly_qb.head(10)
plt.style.use('ggplot')
plt.title('QBs mas relevantes')
plt.pie(x= yearly_qb_rel["pts"], labels= yearly_qb_rel["player"] , autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22c71dea340>,
# ...
#  [Text(1.0259120111074023, 0.3968684233666942, 'Josh Allen'),
#   Text(0.5114699534521022, 0.9738575289618624, 'Justin Herbert*'),
#   Text(-0.22804583535631512, 1.0761018060465473, 'Tom Brady*'),
#   Text(-0.8505112117500501, 0.6975891904892605, 'Patrick Mahomes*'),
#   Text(-1.098553379217019, 0.0563956825552156, 'Aaron Rodgers*+'),
#   Text(-0.9348642507288643, -0.5796799398885211, 'Matthew Stafford'),
#   Text(-0.4480238011507754, -1.0046266339304422, 'Dak Prescott'),
#   Text(0.17754879265177098, -1.0855765409347693, 'Joe Burrow'),
#   Text(0.7380380684178929, -0.8156591258399466, 'Jalen Hurts'),
#   Text(1.0587349371435337, -0.298463285634394, 'Kyler Murray*')],
#  [Text(0.5595883696949466, 0.21647368547274226, '11.75%'),
#   Text(0.27898361097387386, 0.5311950157973794, '11.11%'),
#   Text(-0.12438863746708095, 0.5869646214799348, '10.93%'),
#   Text(-0.46391520640911815, 0.38050319481232386, '10.55%'),
# ...

# %% [markdown]
# cuales fueron los 10 QB con mas pts

# %%
yearly_rel = yearly_1.head(32)
plt.style.use('ggplot')
plt.title('jugadores mas relevantes')
plt.pie(x= yearly_rel["pts"], labels= yearly_rel["player"] , autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22c72e2ffa0>,
# ...
#  [Text(1.0906850298163862, 0.1428501513279872, 'Jonathan Taylor*+'),
#   Text(1.02322220808485, 0.40375278684111143, 'Cooper Kupp*+'),
#   Text(0.9117835943548929, 0.6153459815951285, 'Deebo Samuel*+'),
#   Text(0.72288527627999, 0.8291181323174658, 'Josh Allen'),
#   Text(0.4807298410214132, 0.9893931574210159, 'Austin Ekeler'),
#   Text(0.21436202481142647, 1.0789109890620012, 'Justin Herbert*'),
#   Text(-0.1093037959840162, 1.0945559283031108, 'Tom Brady*'),
#   Text(-0.34817260481330303, 1.0434442185653816, 'Mark Andrews*+'),
#   Text(-0.5133478829543517, 0.972868927999186, "Ja'Marr Chase*"),
#   Text(-0.6743914895545143, 0.8690202062187299, 'Justin Jefferson*'),
#   Text(-0.8212957942381418, 0.731760355831566, 'Joe Mixon*'),
#   Text(-0.9405409602674893, 0.5704232657063607, 'Davante Adams*+'),
#   Text(-1.0451338054197818, 0.34306752800107143, 'Patrick Mahomes*'),
# ...

# %% [markdown]
# los 32 jugadores que mas puntos hicieron

# %%
yearly_rel
# Out:
#                player team pos  age  games  games_started  targets    rec  \
# 0   Jonathan Taylor*+  IND  RB   22     17             17     51.0   40.0
# 1       Cooper Kupp*+  LAR  WR   28     17             17    191.0  145.0
# 2      Deebo Samuel*+  SFO  WR   25     16             15    121.0   77.0
# 3          Josh Allen  BUF  QB   25     17             17      0.0    0.0
# 4       Austin Ekeler  LAC  RB   26     16             16     94.0   70.0
# 5     Justin Herbert*  LAC  QB   23     17             17      0.0    0.0
# 6          Tom Brady*  TAM  QB   44     17             17      0.0    0.0
# 7      Mark Andrews*+  BAL  TE   26     17              9    153.0  107.0
# 8      Ja'Marr Chase*  CIN  WR   21     17             17    128.0   81.0
# 9   Justin Jefferson*  MIN  WR   22     17             17    167.0  108.0
# 10         Joe Mixon*  CIN  RB   25     16             16     48.0   42.0
# 11    Davante Adams*+  GNB  WR   29     16             16    169.0  123.0
# ...

# %%
yearly_rel.value_counts("pos")
# Out:
# pos
# WR    12
# QB     9
# RB     9
# TE     2
# dtype: int64

# %% [markdown]
# cuantos jugadores de cada posicion hay en el top 32

# %%
yearly_1.team.unique()
# Out:
# array(['IND', 'LAR', 'SFO', 'BUF', 'LAC', 'TAM', 'BAL', 'CIN', 'MIN',
#        'GNB', 'KAN', 'PIT', 'ARI', 'DAL', 'CLE', 'SEA', 'NWE', 'PHI',
#        'NOR', 'WAS', 'ATL', 'LVR', 'TEN', 'CAR', 'DEN', 'MIA', 'HOU',
#        'CHI', 'DET', '2TM', 'JAX', 'NYG', 'NYJ', '3TM'], dtype=object)

# %% [markdown]
# se agregan las columnas record, wins y loses que muestran los resultados de la temporada regular de cada equipo

# %%
rcParams['figure.figsize'] = 10,10
sns.heatmap(yearly_1.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
rcParams['figure.figsize'] = 10,10
sns.heatmap(yearly_rel.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
rcParams['figure.figsize'] = 10,10
sns.heatmap(yearly_rb.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
rcParams['figure.figsize'] = 10,10
sns.heatmap(yearly_rb_rel.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
rcParams['figure.figsize'] = 9,9
sns.heatmap(yearly_wr.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
rcParams['figure.figsize'] = 10,10
sns.heatmap(yearly_wr_rel.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
rcParams['figure.figsize'] = 10,10
sns.heatmap(yearly_te.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
rcParams['figure.figsize'] = 10,10
sns.heatmap(yearly_te_rel.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
rcParams['figure.figsize'] = 10,10
sns.heatmap(yearly_qb.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
rcParams['figure.figsize'] = 10, 10
sns.heatmap(yearly_qb_rel.corr(), cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %%
weekly_1["halfppr_pts"].mean()
# Out:
# 8.23082447342026

# %%
def consistencia (x):
    return x/weekly_1["halfppr_pts"].mean()

weekly_1["consistencia"] = weekly_1["halfppr_pts"].apply(consistencia)
weekly_1
# Out:
# <ipython-input-61-f62c1aa0db5e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weekly_1["consistencia"] = weekly_1["halfppr_pts"].apply(consistencia)
#       index           player pos team  pass_yds  pass_td  ints  pass_att  \
# 0         0     Amari Cooper  WR  DAL         0        0     0         0
# 1         1      Tyreek Hill  WR  KAN         0        0     0         0
# 2         2  Patrick Mahomes  QB  KAN       337        3     0        36
# 3         3     Deebo Samuel  WR  SFO         0        0     0         0
# 4         4     Kyler Murray  QB  ARI       289        4     1        32
# ...     ...              ...  ..  ...       ...      ...   ...       ...
# ...

# %% [markdown]
# creo una columna nueva que divide el puntaje del jugador por semana sobre el promedio de la liga es decir que si consistencia es menor a 1 significa que tuvieron menos de 8.23 pts

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\users\tomas\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py:546, in NDFrame._get_axis_number(cls, axis)
#     545 try:
# --> 546     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     547 except KeyError:
#
# KeyError: <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000022C73FBAE20>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 weekly_1.sum(weekly_1.groupby(weekly_1.consistencia))
#
# File c:\users\tomas\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py:10708, in NDFrame._add_numeric_operations.<locals>.sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10688 @doc(
#   10689     _num_doc,
# ...
